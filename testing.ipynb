# %%
import pandas as pd

# %%
# Data Loading & Info

df = pd.read_csv("data/previous_years.csv")
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8990 entries, 0 to 8989
# Data columns (total 44 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   frame_number  8990 non-null   int64
#  1   timestamp     8990 non-null   float64
#  2   center_x_1    8522 non-null   float64
#  3   center_y_1    8522 non-null   float64
#  4   tracked_1     8990 non-null   bool
#  5   center_x_2    8049 non-null   float64
#  6   center_y_2    8049 non-null   float64
#  7   tracked_2     8990 non-null   bool
#  8   center_x_3    8075 non-null   float64
#  9   center_y_3    8075 non-null   float64
#  10  tracked_3     8990 non-null   bool
#  11  center_x_4    8858 non-null   float64
#  12  center_y_4    8858 non-null   float64
#  13  tracked_4     8990 non-null   bool
#  14  center_x_5    8965 non-null   float64
#  15  center_y_5    8965 non-null   float64
#  16  tracked_5     8990 non-null   bool
#  17  center_x_6    4927 non-null   float64
# ...

# %%
# Data Cleansing

df_na = df[]
